# %% [markdown]
# # DE1 — Lab 3: Physical Representations and Batch II Costs
# > Author : Badr TAJINI - Data Engineering I - ESIEE 2025-2026
# ---
#
# Execute all cells. Capture plans and Spark UI evidence.

# %% [markdown]
# ## 0. Setup and explicit schema

# %%
from pyspark.sql import SparkSession, functions as F, types as T
spark = SparkSession.builder.appName("de1-lab3").getOrCreate()

clicks_schema = T.StructType([
    T.StructField("prev_title", T.StringType(), True),
    T.StructField("curr_title", T.StringType(), True),
    T.StructField("type", T.StringType(), True),
    T.StructField("n", T.IntegerType(), True),
    T.StructField("ts", T.TimestampType(), True),
])
dim_schema = T.StructType([
    T.StructField("curr_title", T.StringType(), True),
    T.StructField("curr_category", T.StringType(), True),
])
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/12/30 13:26:41 WARN Utils: Your hostname, maxence-HP-Laptop-14s-dq2xxx, resolves to a loopback address: 127.0.1.1; using 192.168.1.30 instead (on interface wlo1)
# 25/12/30 13:26:41 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/30 13:26:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
import requests
import pandas as pd
import os
from datetime import datetime

def export_spark_metrics(spark, run_id, note="", output_csv="lab3_metrics_log.csv"):
    """
    Exporte les métriques Spark (stages) dans un CSV.
    - spark: SparkSession active
    - run_id: identifiant de ton exécution (ex: "r1", "baseline", etc.)
    - note: commentaire ou variante testée (ex: "broadcast join", etc.)
    - output_csv: nom du fichier de sortie
    """
    ui_url = spark.sparkContext.uiWebUrl
    app_id = spark.sparkContext.applicationId
    
    if not ui_url:
        print("⚠️ Pas d'UI Spark détectée (aucun job en cours ?)")
        return
    
    try:
        # Récupérer les infos de stages
        stages_url = f"{ui_url}/api/v1/applications/{app_id}/stages"
        stages = requests.get(stages_url).json()
    except Exception as e:
        print(f"❌ Erreur API Spark: {e}")
        return
    
    data = []
    for s in stages:
        stage_id = s.get("stageId")
        job_ids = s.get("jobIds", [])
        metrics = s.get("executorSummary", {})
        
        # Métriques de base
        input_bytes = s.get("inputBytes", 0)
        shuffle_read = s.get("shuffleReadBytes", 0)
        shuffle_write = s.get("shuffleWriteBytes", 0)
        num_tasks = s.get("numTasks", 0)
        completion_time = s.get("completionTime", None)
        
        # Fallback pour Spark < 3.x
        if not completion_time and "completionTime" in s.get("completionTime", {}):
            completion_time = s["completionTime"]
        
        data.append({
            "run_id": run_id,
            "job_id": job_ids[0] if job_ids else None,
            "stage_id": stage_id,
            "task": s.get("name", ""),
            "note": note,
            "files_read": s.get("inputRecords", 0),
            "input_size_bytes": input_bytes,
            "shuffle_read_bytes": shuffle_read,
            "shuffle_write_bytes": shuffle_write,
            "timestamp": datetime.now().isoformat()
        })
    
    df = pd.DataFrame(data)
    
    if df.empty:
        print("⚠️ Aucune métrique trouvée (aucun stage terminé ?)")
        return

    # Écrire ou ajouter au CSV
    if os.path.exists(output_csv):
        df.to_csv(output_csv, mode="a", header=False, index=False)
    else:
        df.to_csv(output_csv, index=False)

    print(f"✅ {len(df)} lignes exportées vers {output_csv}")

# %% [markdown]
# ## 1. Ingest monthly CSVs (row format baseline)

# %%
base = "/home/maxence/Documents/data_engineering/"
paths = [f"{base}lab3_clicks_2025-05.csv", f"{base}lab3_clicks_2025-06.csv", f"{base}lab3_clicks_2025-07.csv"]
row_df = (spark.read.schema(clicks_schema).option("header","true").csv(paths)
            .withColumn("year", F.year("ts")).withColumn("month", F.month("ts")))
row_df.cache()
print("Rows:", row_df.count())
row_df.printSchema()
row_df.show(5, truncate=False)

export_spark_metrics(spark, run_id="job0", note="baseline")
# Out:
# Rows: 15000
# root
#  |-- prev_title: string (nullable = true)
#  |-- curr_title: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- n: integer (nullable = true)
#  |-- ts: timestamp (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#
# +-----------------------------+--------------+----+---+-------------------+----+-----+
# |prev_title                   |curr_title    |type|n  |ts                 |year|month|
# +-----------------------------+--------------+----+---+-------------------+----+-----+
# |ETL                          |PySpark       |link|431|2025-06-01 02:57:00|2025|6    |
# |Data_engineering             |Broadcast_join|link|347|2025-06-15 13:40:00|2025|6    |
# |Python_(programming_language)|MapReduce     |link|39 |2025-06-07 15:14:00|2025|6    |
# |ETL                          |Data_warehouse|link|401|2025-06-07 04:59:00|2025|6    |
# |Python_(programming_language)|Dataframe     |link|155|2025-06-06 06:40:00|2025|6    |
# +-----------------------------+--------------+----+---+-------------------+----+-----+
# only showing top 5 rows
# ✅ 5 lignes exportées vers lab3_metrics_log.csv

# %% [markdown]
# ### Evidence: row representation plan

# %%
# Query Q1: top transitions per month for 'link'
q1_row = (row_df.filter(F.col("type")=="link")
           .groupBy("year","month","prev_title","curr_title")
           .agg(F.sum("n").alias("n"))
           .orderBy(F.desc("n"))
           .limit(50))
q1_row.explain("formatted")

import pathlib, datetime as _dt
pathlib.Path("proof").mkdir(exist_ok=True)
with open("proof/plan_row.txt","w") as f:
    f.write(str(_dt.datetime.now())+"\n")
    f.write(q1_row._jdf.queryExecution().executedPlan().toString())
print("Saved proof/plan_row.txt")

export_spark_metrics(spark, run_id="job1", note="baseline")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (11)
# +- TakeOrderedAndProject (10)
#    +- HashAggregate (9)
#       +- Exchange (8)
#          +- HashAggregate (7)
#             +- Project (6)
#                +- Filter (5)
#                   +- InMemoryTableScan (1)
#                         +- InMemoryRelation (2)
#                               +- * Project (4)
#                                  +- Scan csv  (3)
#
#
# (1) InMemoryTableScan
# Output [6]: [curr_title#1, month#7, n#3, prev_title#0, type#2, year#6]
# Arguments: [curr_title#1, month#7, n#3, prev_title#0, type#2, year#6], [isnotnull(type#2), (type#2 = link)]
#
# (2) InMemoryRelation
# Arguments: [prev_title#0, curr_title#1, type#2, n#3, ts#4, year#6, month#7], StorageLevel(disk, memory, deserialized, 1 replicas)
#
# (3) Scan csv
# Output [5]: [prev_title#0, curr_title#1, type#2, n#3, ts#4]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab3_clicks_2025-05.csv, ... 2 entries]
# ReadSchema: struct<prev_title:string,curr_title:string,type:string,n:int,ts:timestamp>
#
# (4) Project [codegen id : 1]
# Output [7]: [prev_title#0, curr_title#1, type#2, n#3, ts#4, year(cast(ts#4 as date)) AS year#6, month(cast(ts#4 as date)) AS month#7]
# Input [5]: [prev_title#0, curr_title#1, type#2, n#3, ts#4]
#
# (5) Filter
# Input [6]: [curr_title#1, month#7, n#3, prev_title#0, type#2, year#6]
# Condition : (isnotnull(type#2) AND (type#2 = link))
#
# (6) Project
# Output [5]: [prev_title#0, curr_title#1, n#3, year#6, month#7]
# Input [6]: [curr_title#1, month#7, n#3, prev_title#0, type#2, year#6]
#
# (7) HashAggregate
# Input [5]: [prev_title#0, curr_title#1, n#3, year#6, month#7]
# Keys [4]: [year#6, month#7, prev_title#0, curr_title#1]
# Functions [1]: [partial_sum(n#3)]
# Aggregate Attributes [1]: [sum#510L]
# Results [5]: [year#6, month#7, prev_title#0, curr_title#1, sum#511L]
#
# (8) Exchange
# Input [5]: [year#6, month#7, prev_title#0, curr_title#1, sum#511L]
# Arguments: hashpartitioning(year#6, month#7, prev_title#0, curr_title#1, 200), ENSURE_REQUIREMENTS, [plan_id=85]
#
# (9) HashAggregate
# Input [5]: [year#6, month#7, prev_title#0, curr_title#1, sum#511L]
# Keys [4]: [year#6, month#7, prev_title#0, curr_title#1]
# Functions [1]: [sum(n#3)]
# Aggregate Attributes [1]: [sum(n#3)#404L]
# Results [5]: [year#6, month#7, prev_title#0, curr_title#1, sum(n#3)#404L AS n#396L]
#
# (10) TakeOrderedAndProject
# Input [5]: [year#6, month#7, prev_title#0, curr_title#1, n#396L]
# Arguments: 50, [n#396L DESC NULLS LAST], [year#6, month#7, prev_title#0, curr_title#1, n#396L]
#
# (11) AdaptiveSparkPlan
# Output [5]: [year#6, month#7, prev_title#0, curr_title#1, n#396L]
# Arguments: isFinalPlan=false
#
#
# Saved proof/plan_row.txt
# ✅ 5 lignes exportées vers lab3_metrics_log.csv

# %% [markdown]
# ## 2. Column representation: Parquet with partitioning and optional sort

# %%
col_base = "outputs/lab3/columnar"
# Write columnar
(row_df
 .write.mode("overwrite")
 .partitionBy("year","month")
 .parquet(f"{col_base}/clicks_parquet"))

# Re‑read columnar for fair comparison
col_df = spark.read.parquet(f"{col_base}/clicks_parquet")
col_df.cache()
print("Columnar rows:", col_df.count())
# Out:
# Columnar rows: 15000

# %% [markdown]
# ### Evidence: column representation plan

# %%
q1_col = (col_df.filter(F.col("type")=="link")
           .groupBy("year","month","prev_title","curr_title")
           .agg(F.sum("n").alias("n"))
           .orderBy(F.desc("n"))
           .limit(50))
q1_col.explain("formatted")
with open("proof/plan_column.txt","w") as f:
    from datetime import datetime as _dt
    f.write(str(_dt.now())+"\n")
    f.write(q1_col._jdf.queryExecution().executedPlan().toString())
print("Saved proof/plan_column.txt")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (11)
# +- TakeOrderedAndProject (10)
#    +- HashAggregate (9)
#       +- Exchange (8)
#          +- HashAggregate (7)
#             +- Project (6)
#                +- Filter (5)
#                   +- InMemoryTableScan (1)
#                         +- InMemoryRelation (2)
#                               +- * ColumnarToRow (4)
#                                  +- Scan parquet  (3)
#
#
# (1) InMemoryTableScan
# Output [6]: [curr_title#655, month#660, n#657, prev_title#654, type#656, year#659]
# Arguments: [curr_title#655, month#660, n#657, prev_title#654, type#656, year#659], [isnotnull(type#656), (type#656 = link)]
#
# (2) InMemoryRelation
# Arguments: [prev_title#654, curr_title#655, type#656, n#657, ts#658, year#659, month#660], StorageLevel(disk, memory, deserialized, 1 replicas)
#
# (3) Scan parquet
# Output [7]: [prev_title#654, curr_title#655, type#656, n#657, ts#658, year#659, month#660]
# Batched: true
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab3-practice/outputs/lab3/columnar/clicks_parquet]
# ReadSchema: struct<prev_title:string,curr_title:string,type:string,n:int,ts:timestamp>
#
# (4) ColumnarToRow [codegen id : 1]
# Input [7]: [prev_title#654, curr_title#655, type#656, n#657, ts#658, year#659, month#660]
#
# (5) Filter
# Input [6]: [curr_title#655, month#660, n#657, prev_title#654, type#656, year#659]
# Condition : (isnotnull(type#656) AND (type#656 = link))
#
# (6) Project
# Output [5]: [prev_title#654, curr_title#655, n#657, year#659, month#660]
# Input [6]: [curr_title#655, month#660, n#657, prev_title#654, type#656, year#659]
#
# (7) HashAggregate
# Input [5]: [prev_title#654, curr_title#655, n#657, year#659, month#660]
# Keys [4]: [year#659, month#660, prev_title#654, curr_title#655]
# Functions [1]: [partial_sum(n#657)]
# Aggregate Attributes [1]: [sum#997L]
# Results [5]: [year#659, month#660, prev_title#654, curr_title#655, sum#998L]
#
# (8) Exchange
# Input [5]: [year#659, month#660, prev_title#654, curr_title#655, sum#998L]
# Arguments: hashpartitioning(year#659, month#660, prev_title#654, curr_title#655, 200), ENSURE_REQUIREMENTS, [plan_id=181]
#
# (9) HashAggregate
# Input [5]: [year#659, month#660, prev_title#654, curr_title#655, sum#998L]
# Keys [4]: [year#659, month#660, prev_title#654, curr_title#655]
# Functions [1]: [sum(n#657)]
# Aggregate Attributes [1]: [sum(n#657)#891L]
# Results [5]: [year#659, month#660, prev_title#654, curr_title#655, sum(n#657)#891L AS n#883L]
#
# (10) TakeOrderedAndProject
# Input [5]: [year#659, month#660, prev_title#654, curr_title#655, n#883L]
# Arguments: 50, [n#883L DESC NULLS LAST], [year#659, month#660, prev_title#654, curr_title#655, n#883L]
#
# (11) AdaptiveSparkPlan
# Output [5]: [year#659, month#660, prev_title#654, curr_title#655, n#883L]
# Arguments: isFinalPlan=false
#
#
# Saved proof/plan_column.txt

# %% [markdown]
# ## 3. Join strategy: normal vs broadcast

# %%
dim = spark.read.schema(dim_schema).option("header","true").csv("/home/maxence/Documents/data_engineering/lab3_dim_curr_category.csv")
# Non‑broadcast join
j1 = (col_df.join(dim, "curr_title", "left")
      .groupBy("curr_category")
      .agg(F.sum("n").alias("total_n"))
      .orderBy(F.desc("total_n")))
j1.explain("formatted")

# Broadcast join
from pyspark.sql.functions import broadcast
j2 = (col_df.join(broadcast(dim), "curr_title", "left")
      .groupBy("curr_category")
      .agg(F.sum("n").alias("total_n"))
      .orderBy(F.desc("total_n")))
j2.explain("formatted")

# Save one plan for evidence
with open("proof/plan_broadcast.txt","w") as f:
    from datetime import datetime as _dt
    f.write(str(_dt.now())+"\n")
    f.write(j2._jdf.queryExecution().executedPlan().toString())
print("Saved proof/plan_broadcast.txt")


export_spark_metrics(spark, run_id="job2", note="baseline")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (15)
# +- Sort (14)
#    +- Exchange (13)
#       +- HashAggregate (12)
#          +- Exchange (11)
#             +- HashAggregate (10)
#                +- Project (9)
#                   +- BroadcastHashJoin LeftOuter BuildRight (8)
#                      :- InMemoryTableScan (1)
#                      :     +- InMemoryRelation (2)
#                      :           +- * ColumnarToRow (4)
#                      :              +- Scan parquet  (3)
#                      +- BroadcastExchange (7)
#                         +- Filter (6)
#                            +- Scan csv  (5)
#
#
# (1) InMemoryTableScan
# Output [2]: [curr_title#655, n#657]
# Arguments: [curr_title#655, n#657]
#
# (2) InMemoryRelation
# Arguments: [prev_title#654, curr_title#655, type#656, n#657, ts#658, year#659, month#660], StorageLevel(disk, memory, deserialized, 1 replicas)
#
# (3) Scan parquet
# Output [7]: [prev_title#654, curr_title#655, type#656, n#657, ts#658, year#659, month#660]
# Batched: true
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab3-practice/outputs/lab3/columnar/clicks_parquet]
# ReadSchema: struct<prev_title:string,curr_title:string,type:string,n:int,ts:timestamp>
#
# (4) ColumnarToRow [codegen id : 1]
# Input [7]: [prev_title#654, curr_title#655, type#656, n#657, ts#658, year#659, month#660]
#
# (5) Scan csv
# Output [2]: [curr_title#999, curr_category#1000]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab3_dim_curr_category.csv]
# PushedFilters: [IsNotNull(curr_title)]
# ReadSchema: struct<curr_title:string,curr_category:string>
#
# (6) Filter
# Input [2]: [curr_title#999, curr_category#1000]
# Condition : isnotnull(curr_title#999)
#
# (7) BroadcastExchange
# Input [2]: [curr_title#999, curr_category#1000]
# Arguments: HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=220]
#
# (8) BroadcastHashJoin
# Left keys [1]: [curr_title#655]
# Right keys [1]: [curr_title#999]
# Join type: LeftOuter
# Join condition: None
#
# (9) Project
# Output [2]: [n#657, curr_category#1000]
# Input [4]: [curr_title#655, n#657, curr_title#999, curr_category#1000]
#
# (10) HashAggregate
# Input [2]: [n#657, curr_category#1000]
# Keys [1]: [curr_category#1000]
# Functions [1]: [partial_sum(n#657)]
# Aggregate Attributes [1]: [sum#1117L]
# Results [2]: [curr_category#1000, sum#1118L]
#
# (11) Exchange
# Input [2]: [curr_category#1000, sum#1118L]
# Arguments: hashpartitioning(curr_category#1000, 200), ENSURE_REQUIREMENTS, [plan_id=225]
#
# (12) HashAggregate
# Input [2]: [curr_category#1000, sum#1118L]
# Keys [1]: [curr_category#1000]
# Functions [1]: [sum(n#657)]
# Aggregate Attributes [1]: [sum(n#657)#1011L]
# Results [2]: [curr_category#1000, sum(n#657)#1011L AS total_n#1002L]
#
# (13) Exchange
# Input [2]: [curr_category#1000, total_n#1002L]
# Arguments: rangepartitioning(total_n#1002L DESC NULLS LAST, 200), ENSURE_REQUIREMENTS, [plan_id=228]
#
# (14) Sort
# Input [2]: [curr_category#1000, total_n#1002L]
# Arguments: [total_n#1002L DESC NULLS LAST], true, 0
#
# (15) AdaptiveSparkPlan
# Output [2]: [curr_category#1000, total_n#1002L]
# Arguments: isFinalPlan=false
#
#
# == Physical Plan ==
# AdaptiveSparkPlan (15)
# +- Sort (14)
#    +- Exchange (13)
#       +- HashAggregate (12)
#          +- Exchange (11)
#             +- HashAggregate (10)
#                +- Project (9)
#                   +- BroadcastHashJoin LeftOuter BuildRight (8)
#                      :- InMemoryTableScan (1)
#                      :     +- InMemoryRelation (2)
#                      :           +- * ColumnarToRow (4)
#                      :              +- Scan parquet  (3)
#                      +- BroadcastExchange (7)
#                         +- Filter (6)
#                            +- Scan csv  (5)
#
#
# (1) InMemoryTableScan
# Output [2]: [curr_title#655, n#657]
# Arguments: [curr_title#655, n#657]
#
# (2) InMemoryRelation
# Arguments: [prev_title#654, curr_title#655, type#656, n#657, ts#658, year#659, month#660], StorageLevel(disk, memory, deserialized, 1 replicas)
#
# (3) Scan parquet
# Output [7]: [prev_title#654, curr_title#655, type#656, n#657, ts#658, year#659, month#660]
# Batched: true
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab3-practice/outputs/lab3/columnar/clicks_parquet]
# ReadSchema: struct<prev_title:string,curr_title:string,type:string,n:int,ts:timestamp>
#
# (4) ColumnarToRow [codegen id : 1]
# Input [7]: [prev_title#654, curr_title#655, type#656, n#657, ts#658, year#659, month#660]
#
# (5) Scan csv
# Output [2]: [curr_title#999, curr_category#1000]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab3_dim_curr_category.csv]
# PushedFilters: [IsNotNull(curr_title)]
# ReadSchema: struct<curr_title:string,curr_category:string>
#
# (6) Filter
# Input [2]: [curr_title#999, curr_category#1000]
# Condition : isnotnull(curr_title#999)
#
# (7) BroadcastExchange
# Input [2]: [curr_title#999, curr_category#1000]
# Arguments: HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=266]
#
# (8) BroadcastHashJoin
# Left keys [1]: [curr_title#655]
# Right keys [1]: [curr_title#999]
# Join type: LeftOuter
# Join condition: None
#
# (9) Project
# Output [2]: [n#657, curr_category#1000]
# Input [4]: [curr_title#655, n#657, curr_title#999, curr_category#1000]
#
# (10) HashAggregate
# Input [2]: [n#657, curr_category#1000]
# Keys [1]: [curr_category#1000]
# Functions [1]: [partial_sum(n#657)]
# Aggregate Attributes [1]: [sum#1234L]
# Results [2]: [curr_category#1000, sum#1235L]
#
# (11) Exchange
# Input [2]: [curr_category#1000, sum#1235L]
# Arguments: hashpartitioning(curr_category#1000, 200), ENSURE_REQUIREMENTS, [plan_id=271]
#
# (12) HashAggregate
# Input [2]: [curr_category#1000, sum#1235L]
# Keys [1]: [curr_category#1000]
# Functions [1]: [sum(n#657)]
# Aggregate Attributes [1]: [sum(n#657)#1128L]
# Results [2]: [curr_category#1000, sum(n#657)#1128L AS total_n#1119L]
#
# (13) Exchange
# Input [2]: [curr_category#1000, total_n#1119L]
# Arguments: rangepartitioning(total_n#1119L DESC NULLS LAST, 200), ENSURE_REQUIREMENTS, [plan_id=274]
#
# (14) Sort
# Input [2]: [curr_category#1000, total_n#1119L]
# Arguments: [total_n#1119L DESC NULLS LAST], true, 0
#
# (15) AdaptiveSparkPlan
# Output [2]: [curr_category#1000, total_n#1119L]
# Arguments: isFinalPlan=false
#
#
# Saved proof/plan_broadcast.txt
# ✅ 11 lignes exportées vers lab3_metrics_log.csv

# %% [markdown]
# ## 4. Additional queries for metrics

# %%
# Q2: daily GMV‑like metric (sum of n) for a specific title window
q2_row = (row_df.filter((F.col("type")=="link") & F.col("curr_title").isin("Apache_Spark","PySpark"))
           .groupBy("year","month","curr_title").agg(F.sum("n").alias("n")).orderBy("year","month","curr_title"))
q2_col = (col_df.filter((F.col("type")=="link") & F.col("curr_title").isin("Apache_Spark","PySpark"))
           .groupBy("year","month","curr_title").agg(F.sum("n").alias("n")).orderBy("year","month","curr_title"))

# Trigger
_ = q2_row.count(); _ = q2_col.count()

# Q3: heavy cardinality grouping
q3_row = row_df.groupBy("prev_title","curr_title").agg(F.sum("n").alias("n")).orderBy(F.desc("n")).limit(100)
q3_col = col_df.groupBy("prev_title","curr_title").agg(F.sum("n").alias("n")).orderBy(F.desc("n")).limit(100)
_ = q3_row.count(); _ = q3_col.count()

print("Open Spark UI at http://localhost:4040 while each job runs and record metrics into lab3_metrics_log.csv")

export_spark_metrics(spark, run_id="job3", note="baseline")
# Out:
# Open Spark UI at http://localhost:4040 while each job runs and record metrics into lab3_metrics_log.csv
# ✅ 29 lignes exportées vers lab3_metrics_log.csv

# %% [markdown]
# ## 5. Save sample outputs

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: numpy>=1.22.4 in /home/maxence/miniconda3/envs/de1-env/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/maxence/miniconda3/envs/de1-env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/maxence/miniconda3/envs/de1-env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 22.5 MB/s  0:00:0023.7 MB/s eta 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]━━━━━━━━━━━ 2/3 [pandas]
# Successfully installed pandas-2.3.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pathlib, pandas as pd
pathlib.Path("outputs/lab3").mkdir(parents=True, exist_ok=True)
q1_row.limit(10).toPandas().to_csv("outputs/lab3/q1_row_top10.csv", index=False)
q1_col.limit(10).toPandas().to_csv("outputs/lab3/q1_col_top10.csv", index=False)
j2.limit(20).toPandas().to_csv("outputs/lab3/j2_broadcast_sample.csv", index=False)
print("Saved sample outputs in outputs/lab3/")
# Out:
# Saved sample outputs in outputs/lab3/

# %% [markdown]
# ## 6. Cleanup

# %%
spark.stop()
print("Spark session stopped.")
# Out:
# Spark session stopped.
