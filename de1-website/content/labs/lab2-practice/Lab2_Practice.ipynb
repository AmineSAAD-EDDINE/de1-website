# %% [markdown]
# # Lab 2 Practice
# > Author : Maxence DELEHELLE, Amine SAAD-EDDINE - Data Engineering 1 - ESIEE 2025-2026
# **Academic year:** 2025–2026
# **Program:** Data & Applications - Engineering - (FD)
# **Course:** Data Engineering I
# ---

# %% [markdown]
# ## 0. Setup and schemas

# %%
from pyspark.sql import SparkSession, functions as F, types as T
spark = SparkSession.builder.appName("de1-lab2").getOrCreate()
base = "/home/maxence/Documents/data_engineering/"
# Explicit schemas
customers_schema = T.StructType([
    T.StructField("customer_id", T.IntegerType(), False),
    T.StructField("name", T.StringType(), True),
    T.StructField("email", T.StringType(), True),
    T.StructField("created_at", T.TimestampType(), True),
])
brands_schema = T.StructType([
    T.StructField("brand_id", T.IntegerType(), False),
    T.StructField("brand_name", T.StringType(), True),
])
categories_schema = T.StructType([
    T.StructField("category_id", T.IntegerType(), False),
    T.StructField("category_name", T.StringType(), True),
])
products_schema = T.StructType([
    T.StructField("product_id", T.IntegerType(), False),
    T.StructField("product_name", T.StringType(), True),
    T.StructField("brand_id", T.IntegerType(), True),
    T.StructField("category_id", T.IntegerType(), True),
    T.StructField("price", T.DoubleType(), True),
])
orders_schema = T.StructType([
    T.StructField("order_id", T.IntegerType(), False),
    T.StructField("customer_id", T.IntegerType(), True),
    T.StructField("order_date", T.TimestampType(), True),
])
order_items_schema = T.StructType([
    T.StructField("order_item_id", T.IntegerType(), False),
    T.StructField("order_id", T.IntegerType(), True),
    T.StructField("product_id", T.IntegerType(), True),
    T.StructField("quantity", T.IntegerType(), True),
    T.StructField("unit_price", T.DoubleType(), True),
])
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/12/30 13:23:58 WARN Utils: Your hostname, maxence-HP-Laptop-14s-dq2xxx, resolves to a loopback address: 127.0.1.1; using 192.168.1.30 instead (on interface wlo1)
# 25/12/30 13:23:58 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/30 13:23:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
import requests
import pandas as pd
import os
from datetime import datetime

def export_spark_metrics(spark, run_id, note="", output_csv="lab2_metrics_log.csv"):
    """
    Exporte les métriques Spark (stages) dans un CSV.
    - spark: SparkSession active
    - run_id: identifiant de ton exécution (ex: "r1", "baseline", etc.)
    - note: commentaire ou variante testée (ex: "broadcast join", etc.)
    - output_csv: nom du fichier de sortie
    """
    ui_url = spark.sparkContext.uiWebUrl
    app_id = spark.sparkContext.applicationId
    
    if not ui_url:
        print("⚠️ Pas d'UI Spark détectée (aucun job en cours ?)")
        return
    
    try:
        # Récupérer les infos de stages
        stages_url = f"{ui_url}/api/v1/applications/{app_id}/stages"
        stages = requests.get(stages_url).json()
    except Exception as e:
        print(f"❌ Erreur API Spark: {e}")
        return
    
    data = []
    for s in stages:
        stage_id = s.get("stageId")
        job_ids = s.get("jobIds", [])
        metrics = s.get("executorSummary", {})
        
        # Métriques de base
        input_bytes = s.get("inputBytes", 0)
        shuffle_read = s.get("shuffleReadBytes", 0)
        shuffle_write = s.get("shuffleWriteBytes", 0)
        num_tasks = s.get("numTasks", 0)
        completion_time = s.get("completionTime", None)
        
        # Fallback pour Spark < 3.x
        if not completion_time and "completionTime" in s.get("completionTime", {}):
            completion_time = s["completionTime"]
        
        data.append({
            "run_id": run_id,
            "job_id": job_ids[0] if job_ids else None,
            "stage_id": stage_id,
            "task": s.get("name", ""),
            "note": note,
            "files_read": s.get("inputRecords", 0),
            "input_size_bytes": input_bytes,
            "shuffle_read_bytes": shuffle_read,
            "shuffle_write_bytes": shuffle_write,
            "timestamp": datetime.now().isoformat()
        })
    
    df = pd.DataFrame(data)
    
    if df.empty:
        print("⚠️ Aucune métrique trouvée (aucun stage terminé ?)")
        return

    # Écrire ou ajouter au CSV
    if os.path.exists(output_csv):
        df.to_csv(output_csv, mode="a", header=False, index=False)
    else:
        df.to_csv(output_csv, index=False)

    print(f"✅ {len(df)} lignes exportées vers {output_csv}")

# %% [markdown]
# ## 1. Ingest operational tables (from CSV exports)

# %%
customers = spark.read.schema(customers_schema).option("header","true").csv(base+"lab2_customers.csv")
brands = spark.read.schema(brands_schema).option("header","true").csv(base+"lab2_brands.csv")
categories = spark.read.schema(categories_schema).option("header","true").csv(base+"lab2_categories.csv")
products = spark.read.schema(products_schema).option("header","true").csv(base+"lab2_products.csv")
orders = spark.read.schema(orders_schema).option("header","true").csv(base+"lab2_orders.csv")
order_items = spark.read.schema(order_items_schema).option("header","true").csv(base+"lab2_order_items.csv")

for name, df in [("customers",customers),("brands",brands),("categories",categories),("products",products),("orders",orders),("order_items",order_items)]:
    print(name, df.count())

export_spark_metrics(spark, run_id="job0", note="baseline")
# Out:
# customers 24
# brands 8
# categories 9
# products 60
# orders 220
# order_items 638
# ✅ 36 lignes exportées vers lab2_metrics_log.csv

# %% [markdown]
# ### Evidence: ingestion plan

# %%
ingest = orders.join(order_items, "order_id").select("order_id").distinct()
ingest.explain("formatted")
from datetime import datetime as _dt
import pathlib
pathlib.Path("proof").mkdir(exist_ok=True)
with open("proof/plan_ingest.txt","w") as f:
    f.write(str(_dt.now())+"\n")
    f.write(ingest._jdf.queryExecution().executedPlan().toString())
print("Saved proof/plan_ingest.txt")

export_spark_metrics(spark, run_id="job1", note="baseline")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (11)
# +- HashAggregate (10)
#    +- Exchange (9)
#       +- HashAggregate (8)
#          +- Project (7)
#             +- BroadcastHashJoin Inner BuildLeft (6)
#                :- BroadcastExchange (3)
#                :  +- Filter (2)
#                :     +- Scan csv  (1)
#                +- Filter (5)
#                   +- Scan csv  (4)
#
#
# (1) Scan csv
# Output [1]: [order_id#79]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_orders.csv]
# PushedFilters: [IsNotNull(order_id)]
# ReadSchema: struct<order_id:int>
#
# (2) Filter
# Input [1]: [order_id#79]
# Condition : isnotnull(order_id#79)
#
# (3) BroadcastExchange
# Input [1]: [order_id#79]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=407]
#
# (4) Scan csv
# Output [1]: [order_id#83]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_order_items.csv]
# PushedFilters: [IsNotNull(order_id)]
# ReadSchema: struct<order_id:int>
#
# (5) Filter
# Input [1]: [order_id#83]
# Condition : isnotnull(order_id#83)
#
# (6) BroadcastHashJoin
# Left keys [1]: [order_id#79]
# Right keys [1]: [order_id#83]
# Join type: Inner
# Join condition: None
#
# (7) Project
# Output [1]: [order_id#79]
# Input [2]: [order_id#79, order_id#83]
#
# (8) HashAggregate
# Input [1]: [order_id#79]
# Keys [1]: [order_id#79]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [order_id#79]
#
# (9) Exchange
# Input [1]: [order_id#79]
# Arguments: hashpartitioning(order_id#79, 200), ENSURE_REQUIREMENTS, [plan_id=412]
#
# (10) HashAggregate
# Input [1]: [order_id#79]
# Keys [1]: [order_id#79]
# Functions: []
# Aggregate Attributes: []
# Results [1]: [order_id#79]
#
# (11) AdaptiveSparkPlan
# Output [1]: [order_id#79]
# Arguments: isFinalPlan=false
#
#
# Saved proof/plan_ingest.txt
# ✅ 36 lignes exportées vers lab2_metrics_log.csv

# %% [markdown]
# ## 2. Surrogate key function

# %%
def sk(cols):
    # stable 64-bit positive surrogate key from natural keys
    return F.abs(F.xxhash64(*[F.col(c) for c in cols]))

# %% [markdown]
# ## 3. Build dimensions

# %%
dim_customer = customers.select(
    sk(["customer_id"]).alias("customer_sk"),
    "customer_id","name","email","created_at"
)

dim_brand = brands.select(
    sk(["brand_id"]).alias("brand_sk"),
    "brand_id","brand_name"
)

dim_category = categories.select(
    sk(["category_id"]).alias("category_sk"),
    "category_id","category_name"
)

dim_product = products.select(
    sk(["product_id"]).alias("product_sk"),
    "product_id","product_name",
    sk(["brand_id"]).alias("brand_sk"),
    sk(["category_id"]).alias("category_sk"),
    "price"
)

export_spark_metrics(spark, run_id="job3", note="baseline")
# Out:
# ✅ 36 lignes exportées vers lab2_metrics_log.csv

# %% [markdown]
# ## 4. Build date dimension

# %%
from pyspark.sql import Window as W
dates = orders.select(F.to_date("order_date").alias("date")).distinct()
dim_date = dates.select(
    sk(["date"]).alias("date_sk"),
    F.col("date"),
    F.year("date").alias("year"),
    F.month("date").alias("month"),
    F.dayofmonth("date").alias("day"),
    F.date_format("date","E").alias("dow")
)

export_spark_metrics(spark, run_id="job4", note="baseline")
# Out:
# ✅ 36 lignes exportées vers lab2_metrics_log.csv

# %% [markdown]
# ## 5. Build fact_sales with broadcast joins where appropriate

# %%
oi = order_items.alias("oi")
p = products.alias("p")
o = orders.alias("o")
c = customers.alias("c")

# Join with small dimensions using DF copies to compute SKs, then broadcast dims by size heuristic
df_fact = (oi
    .join(p, F.col("oi.product_id")==F.col("p.product_id"))
    .drop(oi.product_id)
    .join(o, "order_id")
    .join(c, "customer_id")
    .withColumn("date", F.to_date("order_date"))
)

# Attach surrogate keys
df_fact = (df_fact
    .withColumn("date_sk", sk(["date"]))
    .withColumn("customer_sk", sk(["customer_id"]))
    .withColumn("product_sk", sk(["product_id"]))
    .withColumn("quantity", F.col("quantity").cast("int"))
    .withColumn("unit_price", F.col("unit_price").cast("double"))
    .withColumn("subtotal", F.col("quantity")*F.col("unit_price"))
    .withColumn("year", F.year("date"))
    .withColumn("month", F.month("date"))
    .select("order_id","date_sk","customer_sk","product_sk","quantity","unit_price","subtotal","year","month")
)

df_fact.explain("formatted")
with open("proof/plan_fact_join.txt","w") as f:
    from datetime import datetime as _dt
    f.write(str(_dt.now())+"\n")
    f.write(df_fact._jdf.queryExecution().executedPlan().toString())
print("Saved proof/plan_fact_join.txt")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (19)
# +- Project (18)
#    +- Project (17)
#       +- BroadcastHashJoin Inner BuildRight (16)
#          :- Project (12)
#          :  +- BroadcastHashJoin Inner BuildRight (11)
#          :     :- Project (7)
#          :     :  +- BroadcastHashJoin Inner BuildRight (6)
#          :     :     :- Filter (2)
#          :     :     :  +- Scan csv  (1)
#          :     :     +- BroadcastExchange (5)
#          :     :        +- Filter (4)
#          :     :           +- Scan csv  (3)
#          :     +- BroadcastExchange (10)
#          :        +- Filter (9)
#          :           +- Scan csv  (8)
#          +- BroadcastExchange (15)
#             +- Filter (14)
#                +- Scan csv  (13)
#
#
# (1) Scan csv
# Output [4]: [order_id#83, product_id#84, quantity#85, unit_price#86]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_order_items.csv]
# PushedFilters: [IsNotNull(product_id), IsNotNull(order_id)]
# ReadSchema: struct<order_id:int,product_id:int,quantity:int,unit_price:double>
#
# (2) Filter
# Input [4]: [order_id#83, product_id#84, quantity#85, unit_price#86]
# Condition : (isnotnull(product_id#84) AND isnotnull(order_id#83))
#
# (3) Scan csv
# Output [1]: [product_id#74]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_products.csv]
# PushedFilters: [IsNotNull(product_id)]
# ReadSchema: struct<product_id:int>
#
# (4) Filter
# Input [1]: [product_id#74]
# Condition : isnotnull(product_id#74)
#
# (5) BroadcastExchange
# Input [1]: [product_id#74]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=481]
#
# (6) BroadcastHashJoin
# Left keys [1]: [product_id#84]
# Right keys [1]: [product_id#74]
# Join type: Inner
# Join condition: None
#
# (7) Project
# Output [4]: [order_id#83, quantity#85, unit_price#86, product_id#74]
# Input [5]: [order_id#83, product_id#84, quantity#85, unit_price#86, product_id#74]
#
# (8) Scan csv
# Output [3]: [order_id#79, customer_id#80, order_date#81]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_orders.csv]
# PushedFilters: [IsNotNull(order_id), IsNotNull(customer_id)]
# ReadSchema: struct<order_id:int,customer_id:int,order_date:timestamp>
#
# (9) Filter
# Input [3]: [order_id#79, customer_id#80, order_date#81]
# Condition : (isnotnull(order_id#79) AND isnotnull(customer_id#80))
#
# (10) BroadcastExchange
# Input [3]: [order_id#79, customer_id#80, order_date#81]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=485]
#
# (11) BroadcastHashJoin
# Left keys [1]: [order_id#83]
# Right keys [1]: [order_id#79]
# Join type: Inner
# Join condition: None
#
# (12) Project
# Output [6]: [order_id#83, quantity#85, unit_price#86, product_id#74, customer_id#80, order_date#81]
# Input [7]: [order_id#83, quantity#85, unit_price#86, product_id#74, order_id#79, customer_id#80, order_date#81]
#
# (13) Scan csv
# Output [1]: [customer_id#66]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_customers.csv]
# PushedFilters: [IsNotNull(customer_id)]
# ReadSchema: struct<customer_id:int>
#
# (14) Filter
# Input [1]: [customer_id#66]
# Condition : isnotnull(customer_id#66)
#
# (15) BroadcastExchange
# Input [1]: [customer_id#66]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=489]
#
# (16) BroadcastHashJoin
# Left keys [1]: [customer_id#80]
# Right keys [1]: [customer_id#66]
# Join type: Inner
# Join condition: None
#
# (17) Project
# Output [6]: [customer_id#80, order_id#83, quantity#85, unit_price#86, product_id#74, cast(order_date#81 as date) AS date#150]
# Input [7]: [order_id#83, quantity#85, unit_price#86, product_id#74, customer_id#80, order_date#81, customer_id#66]
#
# (18) Project
# Output [9]: [order_id#83, abs(xxhash64(date#150, 42)) AS date_sk#151L, abs(xxhash64(customer_id#80, 42)) AS customer_sk#152L, abs(xxhash64(product_id#74, 42)) AS product_sk#153L, quantity#85, unit_price#86, (cast(quantity#85 as double) * unit_price#86) AS subtotal#156, year(date#150) AS year#157, month(date#150) AS month#158]
# Input [6]: [customer_id#80, order_id#83, quantity#85, unit_price#86, product_id#74, date#150]
#
# (19) AdaptiveSparkPlan
# Output [9]: [order_id#83, date_sk#151L, customer_sk#152L, product_sk#153L, quantity#85, unit_price#86, subtotal#156, year#157, month#158]
# Arguments: isFinalPlan=false
#
#
# Saved proof/plan_fact_join.txt

# %% [markdown]
# ## 6. Write Parquet outputs (partitioned by year, month)

# %%
base_out = "/home/maxence/Documents/data_engineering/"
(dim_customer.write.mode("overwrite").parquet(f"{base_out}/dim_customer"))
(dim_brand.write.mode("overwrite").parquet(f"{base_out}/dim_brand"))
(dim_category.write.mode("overwrite").parquet(f"{base_out}/dim_category"))
(dim_product.write.mode("overwrite").parquet(f"{base_out}/dim_product"))
(dim_date.write.mode("overwrite").parquet(f"{base_out}/dim_date"))
(df_fact.write.mode("overwrite").partitionBy("year","month").parquet(f"{base_out}/fact_sales"))
print("Parquet written under outputs/lab2/")
# Out:
# [Stage 36:>                                                         (0 + 1) / 1]
# Parquet written under outputs/lab2/

# %% [markdown]
# ## 7. Plan comparison: projection and layout

# %%
# Case A: join and then project
a = (orders.join(order_items, "order_id")
            .join(products, "product_id")
            .groupBy(F.to_date("order_date").alias("d"))
            .agg(F.sum(F.col("quantity")*F.col("price")).alias("gmv")))
a.explain("formatted")
_ = a.count()

# Case B: project early
b = (orders.select("order_id","order_date")
            .join(order_items.select("order_id","product_id","quantity"), "order_id")
            .join(products.select("product_id","price"), "product_id")
            .groupBy(F.to_date("order_date").alias("d"))
            .agg(F.sum(F.col("quantity")*F.col("price")).alias("gmv")))
b.explain("formatted")
_ = b.count()

print("Record Spark UI metrics for both runs in lab2_metrics_log.csv")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (16)
# +- HashAggregate (15)
#    +- Exchange (14)
#       +- HashAggregate (13)
#          +- Project (12)
#             +- BroadcastHashJoin Inner BuildRight (11)
#                :- Project (7)
#                :  +- BroadcastHashJoin Inner BuildLeft (6)
#                :     :- BroadcastExchange (3)
#                :     :  +- Filter (2)
#                :     :     +- Scan csv  (1)
#                :     +- Filter (5)
#                :        +- Scan csv  (4)
#                +- BroadcastExchange (10)
#                   +- Filter (9)
#                      +- Scan csv  (8)
#
#
# (1) Scan csv
# Output [2]: [order_id#79, order_date#81]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_orders.csv]
# PushedFilters: [IsNotNull(order_id)]
# ReadSchema: struct<order_id:int,order_date:timestamp>
#
# (2) Filter
# Input [2]: [order_id#79, order_date#81]
# Condition : isnotnull(order_id#79)
#
# (3) BroadcastExchange
# Input [2]: [order_id#79, order_date#81]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=956]
#
# (4) Scan csv
# Output [3]: [order_id#83, product_id#84, quantity#85]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_order_items.csv]
# PushedFilters: [IsNotNull(order_id), IsNotNull(product_id)]
# ReadSchema: struct<order_id:int,product_id:int,quantity:int>
#
# (5) Filter
# Input [3]: [order_id#83, product_id#84, quantity#85]
# Condition : (isnotnull(order_id#83) AND isnotnull(product_id#84))
#
# (6) BroadcastHashJoin
# Left keys [1]: [order_id#79]
# Right keys [1]: [order_id#83]
# Join type: Inner
# Join condition: None
#
# (7) Project
# Output [3]: [order_date#81, product_id#84, quantity#85]
# Input [5]: [order_id#79, order_date#81, order_id#83, product_id#84, quantity#85]
#
# (8) Scan csv
# Output [2]: [product_id#74, price#78]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_products.csv]
# PushedFilters: [IsNotNull(product_id)]
# ReadSchema: struct<product_id:int,price:double>
#
# (9) Filter
# Input [2]: [product_id#74, price#78]
# Condition : isnotnull(product_id#74)
#
# (10) BroadcastExchange
# Input [2]: [product_id#74, price#78]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=960]
#
# (11) BroadcastHashJoin
# Left keys [1]: [product_id#84]
# Right keys [1]: [product_id#74]
# Join type: Inner
# Join condition: None
#
# (12) Project
# Output [3]: [quantity#85, price#78, cast(order_date#81 as date) AS _groupingexpression#196]
# Input [5]: [order_date#81, product_id#84, quantity#85, product_id#74, price#78]
#
# (13) HashAggregate
# Input [3]: [quantity#85, price#78, _groupingexpression#196]
# Keys [1]: [_groupingexpression#196]
# Functions [1]: [partial_sum((cast(quantity#85 as double) * price#78))]
# Aggregate Attributes [1]: [sum#197]
# Results [2]: [_groupingexpression#196, sum#198]
#
# (14) Exchange
# Input [2]: [_groupingexpression#196, sum#198]
# Arguments: hashpartitioning(_groupingexpression#196, 200), ENSURE_REQUIREMENTS, [plan_id=965]
#
# (15) HashAggregate
# Input [2]: [_groupingexpression#196, sum#198]
# Keys [1]: [_groupingexpression#196]
# Functions [1]: [sum((cast(quantity#85 as double) * price#78))]
# Aggregate Attributes [1]: [sum((cast(quantity#85 as double) * price#78))#195]
# Results [2]: [_groupingexpression#196 AS d#182, sum((cast(quantity#85 as double) * price#78))#195 AS gmv#183]
#
# (16) AdaptiveSparkPlan
# Output [2]: [d#182, gmv#183]
# Arguments: isFinalPlan=false
#
#
# == Physical Plan ==
# AdaptiveSparkPlan (16)
# +- HashAggregate (15)
#    +- Exchange (14)
#       +- HashAggregate (13)
#          +- Project (12)
#             +- BroadcastHashJoin Inner BuildRight (11)
#                :- Project (7)
#                :  +- BroadcastHashJoin Inner BuildLeft (6)
#                :     :- BroadcastExchange (3)
#                :     :  +- Filter (2)
#                :     :     +- Scan csv  (1)
#                :     +- Filter (5)
#                :        +- Scan csv  (4)
#                +- BroadcastExchange (10)
#                   +- Filter (9)
#                      +- Scan csv  (8)
#
#
# (1) Scan csv
# Output [2]: [order_id#79, order_date#81]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_orders.csv]
# PushedFilters: [IsNotNull(order_id)]
# ReadSchema: struct<order_id:int,order_date:timestamp>
#
# (2) Filter
# Input [2]: [order_id#79, order_date#81]
# Condition : isnotnull(order_id#79)
#
# (3) BroadcastExchange
# Input [2]: [order_id#79, order_date#81]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=1331]
#
# (4) Scan csv
# Output [3]: [order_id#83, product_id#84, quantity#85]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_order_items.csv]
# PushedFilters: [IsNotNull(order_id), IsNotNull(product_id)]
# ReadSchema: struct<order_id:int,product_id:int,quantity:int>
#
# (5) Filter
# Input [3]: [order_id#83, product_id#84, quantity#85]
# Condition : (isnotnull(order_id#83) AND isnotnull(product_id#84))
#
# (6) BroadcastHashJoin
# Left keys [1]: [order_id#79]
# Right keys [1]: [order_id#83]
# Join type: Inner
# Join condition: None
#
# (7) Project
# Output [3]: [order_date#81, product_id#84, quantity#85]
# Input [5]: [order_id#79, order_date#81, order_id#83, product_id#84, quantity#85]
#
# (8) Scan csv
# Output [2]: [product_id#74, price#78]
# Batched: false
# Location: InMemoryFileIndex [file:/home/maxence/Documents/data_engineering/lab2_products.csv]
# PushedFilters: [IsNotNull(product_id)]
# ReadSchema: struct<product_id:int,price:double>
#
# (9) Filter
# Input [2]: [product_id#74, price#78]
# Condition : isnotnull(product_id#74)
#
# (10) BroadcastExchange
# Input [2]: [product_id#74, price#78]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=1335]
#
# (11) BroadcastHashJoin
# Left keys [1]: [product_id#84]
# Right keys [1]: [product_id#74]
# Join type: Inner
# Join condition: None
#
# (12) Project
# Output [3]: [quantity#85, price#78, cast(order_date#81 as date) AS _groupingexpression#219]
# Input [5]: [order_date#81, product_id#84, quantity#85, product_id#74, price#78]
#
# (13) HashAggregate
# Input [3]: [quantity#85, price#78, _groupingexpression#219]
# Keys [1]: [_groupingexpression#219]
# Functions [1]: [partial_sum((cast(quantity#85 as double) * price#78))]
# Aggregate Attributes [1]: [sum#220]
# Results [2]: [_groupingexpression#219, sum#221]
#
# (14) Exchange
# Input [2]: [_groupingexpression#219, sum#221]
# Arguments: hashpartitioning(_groupingexpression#219, 200), ENSURE_REQUIREMENTS, [plan_id=1340]
#
# (15) HashAggregate
# Input [2]: [_groupingexpression#219, sum#221]
# Keys [1]: [_groupingexpression#219]
# Functions [1]: [sum((cast(quantity#85 as double) * price#78))]
# Aggregate Attributes [1]: [sum((cast(quantity#85 as double) * price#78))#218]
# Results [2]: [_groupingexpression#219 AS d#211, sum((cast(quantity#85 as double) * price#78))#218 AS gmv#212]
#
# (16) AdaptiveSparkPlan
# Output [2]: [d#211, gmv#212]
# Arguments: isFinalPlan=false
#
#
# Record Spark UI metrics for both runs in lab2_metrics_log.csv

# %% [markdown]
# ## 8. Cleanup

# %%
spark.stop()
print("Spark session stopped.")
# Out:
# Spark session stopped.

# %% [markdown]
# Rappel : se souvenir que j'ai rajouté la colonne .drop(p.product_id)
